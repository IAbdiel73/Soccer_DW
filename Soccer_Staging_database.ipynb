# %%
import pandas as pd

# %%
from get_soccer_data import get_soccer_data

# %%
import logging
import traceback

# Configure the error logger 
logging.basicConfig(
    filename='error_log.txt',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def log_exception(e: Exception):
    """Logs an exception with full traceback to error_log.txt"""
    logging.error("Exception occurred: \n%s", traceback.format_exc())

# %%
import pandas as pd

def prepare_df(df: pd.DataFrame, column:str = None, new_column:str = None)-> pd.DataFrame:
    """
    Prepare dataframe to be ingested in postgresql,replace table name reserved to database, 
    Change empty strings to 'None' values, replaces all 'NaN' values in the DataFrame with 'None',
    column names to lower case.
    
    Parameters:
    - df: DataFrame to prepare 
    - column: Dataframe column name to be renamed (optional)
    - new_column: New column name (optional)
    """
    if column is not None and new_column is not None:
        df.rename(columns={column:new_column}, inplace= True)
    
    df = df.replace(r'^\s*$', None, regex=True)
    df = df.where(pd.notnull(df), None)
    df.columns = df.columns.str.lower()
    return df

# %%
## Create connection to sql, loading enviromental variables

import psycopg2
from dotenv import load_dotenv
import os

load_dotenv(override=True) 
host = os.getenv("DB_HOST")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_NAME")

pgconn = psycopg2.connect(
    host= host,
    user = user,
    password= password,
    database = database
)


pgcursor = pgconn.cursor()

from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

pgcursor.execute('SELECT current_database()') # Test the connection
pgcursor.fetchone()
# Out:
# ('soccerdatawarehouse',)

# %%
from sqlalchemy import create_engine


def df_to_posgres (user:str, host:str, password:str, database:str, df:pd.DataFrame, db_table:str,schema:str):
    """
    Saves DataFrame in database connected 
    
    Parameters:
    - user: posgresql database connection user
    - host: posgresql database connection host
    - password: posgresql database connection host password
    - database: posgresql database name to connect
    - df: DataFrame to save in database
    - db_table: database table in posgresql
    - schema: schema where the db_table is located
    """

    engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}/{database}?options=-csearch_path%3D{schema}')

    df.to_sql(db_table, engine, if_exists='append',index=False)

# %%
## Create staging schema in soccerwarehouse database
schema_name = "staging"
pgcursor.execute(f"CREATE SCHEMA IF NOT EXISTS {schema_name};")

# Commit the transaction
pgconn.commit()

# %%
## Create Table schedule in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.schedule 
(                 
   GameId                   INT
  , RoundId                 INT
  , Season                  INT
  , SeasonType              INT
  , Group_num               INT
  , AwayTeamId              INT
  , HomeTeamId              INT
  , VenueId                 INT
  , Day                     DATE
  , DateTime                TIMESTAMP
  , Status                  VARCHAR(50)
  , Week                    INT
  , Winner                  VARCHAR(50)
  , VenueType               VARCHAR(50)
  , AwayTeamKey             VARCHAR(50)
  , AwayTeamName            VARCHAR(50)
  , AwayTeamCountryCode     VARCHAR(50)
  , AwayTeamScore           INT
  , AwayTeamScorePeriod1    INT
  , AwayTeamScorePeriod2    INT
  , AwayTeamScoreExtraTime  INT
  , AwayTeamScorePenalty    INT
  , HomeTeamKey             VARCHAR(50)
  , HomeTeamName            VARCHAR(50)
  , HomeTeamCountryCode     VARCHAR(50)
  , HomeTeamScore           INT
  , HomeTeamScorePeriod1    INT
  , HomeTeamScorePeriod2    INT
  , HomeTeamScoreExtraTime  INT
  , HomeTeamScorePenalty    INT
  , Updated                 TIMESTAMP
  , UpdatedUtc              TIMESTAMP
  , GlobalGameId            INT
  , GlobalAwayTeamId        INT
  , GlobalHomeTeamId        INT
  , IsClosed                BOOLEAN
  , PlayoffAggregateScore   INT
);
""")

# %%
## Create Table games in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.games 
(                 
    GameId                    INT
  , RoundId                   INT
  , Season                    INT
  , SeasonType                INT
  , Group_num                 INT
  , AwayTeamId                INT
  , HomeTeamId                INT
  , VenueId                   INT
  , Day                       TIMESTAMP
  , DateTime                  TIMESTAMP
  , Status                    VARCHAR(255)
  , Week                      INT
  , Period                    VARCHAR(255)
  , Clock                     TIMESTAMP
  , Winner                    VARCHAR(255)
  , VenueType                 VARCHAR(255)
  , AwayTeamKey               VARCHAR(255)
  , AwayTeamName              VARCHAR(255)
  , AwayTeamCountryCode       VARCHAR(255)
  , AwayTeamScore             INT
  , AwayTeamScorePeriod1      INT
  , AwayTeamScorePeriod2      INT
  , AwayTeamScoreExtraTime    TIMESTAMP
  , AwayTeamScorePenalty      TIMESTAMP
  , HomeTeamKey               VARCHAR(255)
  , HomeTeamName              VARCHAR(255)
  , HomeTeamCountryCode       VARCHAR(255)
  , HomeTeamScore             INT
  , HomeTeamScorePeriod1      INT
  , HomeTeamScorePeriod2      INT
  , HomeTeamScoreExtraTime    INT
  , HomeTeamScorePenalty      INT
  , HomeTeamMoneyLine         INT
  , AwayTeamMoneyLine         INT
  , DrawMoneyLine             INT
  , PointSpread               FLOAT
  , HomeTeamPointSpreadPayout INT
  , AwayTeamPointSpreadPayout INT
  , OverUnder                 FLOAT
  , OverPayout                INT
  , UnderPayout               INT
  , Attendance                INT
  , Updated                   TIMESTAMP
  , UpdatedUtc                TIMESTAMP
  , GlobalGameId              INT
  , GlobalAwayTeamId          INT
  , GlobalHomeTeamId          INT
  , ClockExtra                TIMESTAMP
  , ClockDisplay              TIMESTAMP
  , IsClosed                  BOOLEAN
  , HomeTeamFormation         VARCHAR(255)
  , AwayTeamFormation         VARCHAR(255)
  , PlayoffAggregateScore     TIMESTAMP
  , awayteamcoachid           INT
  , hometeamcoachid           INT
  , mainreferee               INT
  , assistantreferee1         INT
  , assistantreferee2         INT
  , fourthreferee             INT
  , videoassistantreferee     INT                
);
""")

# %%
## Create Table referees in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.referees 
(                 
    RefereeId     INT
  , FirstName     VARCHAR(50)
  , LastName      VARCHAR(50)
  , ShortName     VARCHAR(50)
  , Nationality   VARCHAR(50)
);
""")

# %%
## Create Table coaches in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.coaches
(                 
    CoachId      INT
  , FirstName    VARCHAR(50)
  , LastName     VARCHAR(50)
  , ShortName    VARCHAR(50)
  , Nationality  VARCHAR(50)
);
""")

# %%
## Create Table goals in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.goals 
(                 
    GoalId                  INT
  , GameId                  INT
  , TeamId                  INT
  , PlayerId                INT
  , Name                    VARCHAR(50)
  , Type                    VARCHAR(50)
  , AssistedByPlayerId1     INT
  , AssistedByPlayerName1   VARCHAR(50)
  , AssistedByPlayerId2     INT
  , AssistedByPlayerName2   VARCHAR(50)
  , GameMinute              INT
  , GameMinuteExtra         INT
);
""")

# %%
## Create Table lineups in staging schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.lineups 
(                 
    LineupId                    INT
  , GameId                      INT
  , Type                        VARCHAR(100)
  , TeamId                      INT
  , PlayerId                    VARCHAR(50)
  , Name                        VARCHAR(50)
  , Position                    VARCHAR(50)
  , ReplacedPlayerId            INT
  , ReplacedPlayerName          VARCHAR(50)
  , GameMinute                  VARCHAR(50)
  , GameMinuteExtra             INT
  , PitchPositionHorizontal     FLOAT
  , PitchPositionVertical       FLOAT
);
""")

# %%
## Create Table schedule in bookings schema 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.bookings
(                 
    BookingId         INT
  , GameId            INT
  , Type              VARCHAR(100)
  , TeamId            INT
  , PlayerId          VARCHAR(50)
  , Name              VARCHAR(50)
  , GameMinute        INT
  , GameMinuteExtra   VARCHAR(50)
);
""")

# %%
## Create Table schedule in staging teamgames 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.teamgames 
(
    StatId                         INT
    , SeasonType                    INT
    , Season                        INT
    , RoundId                       INT
    , TeamId                        INT
    , Name                          VARCHAR(255)
    , Team                          VARCHAR(255)
    , GlobalTeamId                  INT
    , Possession                    FLOAT
    , GameId                        INT
    , OpponentId                    INT
    , Opponent                      VARCHAR(255)
    , Day                           TIMESTAMP
    , DateTime                      TIMESTAMP
    , HomeOrAway                    VARCHAR(255)
    , IsGameOver                    BOOLEAN
    , GlobalGameId                  INT
    , GlobalOpponentId              INT
    , Updated                       TIMESTAMP
    , UpdatedUtc                    TIMESTAMP
    , Games                         INT
    , FantasyPoints                 FLOAT
    , FantasyPointsFanDuel          VARCHAR(50)
    , FantasyPointsDraftKings       FLOAT
    , FantasyPointsYahoo            VARCHAR(50)
    , FantasyPointsMondogoal        FLOAT
    , Minutes                       FLOAT
    , Goals                         FLOAT
    , Assists                       FLOAT
    , Shots                         FLOAT
    , ShotsOnGoal                   FLOAT
    , YellowCards                   FLOAT
    , RedCards                      FLOAT
    , YellowRedCards                FLOAT
    , Crosses                       FLOAT
    , TacklesWon                    FLOAT
    , Interceptions                 FLOAT
    , OwnGoals                      FLOAT
    , Fouls                         FLOAT
    , Fouled                        FLOAT
    , Offsides                      FLOAT
    , Passes                        FLOAT
    , PassesCompleted               FLOAT
    , LastManTackle                 FLOAT
    , CornersWon                    FLOAT
    , BlockedShots                  FLOAT
    , Touches                       FLOAT
    , DefenderCleanSheets           FLOAT
    , GoalkeeperSaves               FLOAT
    , GoalkeeperGoalsAgainst        FLOAT
    , GoalkeeperSingleGoalAgainst   FLOAT
    , GoalkeeperCleanSheets         FLOAT
    , GoalkeeperWins                FLOAT
    , PenaltyKickGoals              FLOAT
    , PenaltyKickMisses             FLOAT
    , PenaltyKickSaves              FLOAT
    , PenaltiesWon                  FLOAT
    , PenaltiesConceded             FLOAT
    , Score                         FLOAT
    , OpponentScore                 FLOAT
    , Tackles                       FLOAT
);
""")

# %%
## Create Table schedule in staging playerteams 
pgcursor.execute("""
 CREATE TABLE IF NOT EXISTS staging.playerteams 
( 
     StatId                         INT
    , SeasonType                    INT
    , Season                        INT
    , RoundId                       INT
    , TeamId                        INT
    , PlayerId                      INT
    , Name                          VARCHAR(150)
    , ShortName                     VARCHAR(50)
    , Team                          VARCHAR(255)
    , PositionCategory              VARCHAR(10)
    , Position                      VARCHAR(10)
    , Jersey                        INT
    , Started                       INT
    , Captain                       BOOLEAN
    , Suspension                    BOOLEAN
    , SuspensionReason              VARCHAR(255)
    , FanDuelSalary                 VARCHAR(255)
    , DraftKingsSalary              VARCHAR(255)
    , YahooSalary                   VARCHAR(255)
    , MondogoalSalary               VARCHAR(255)
    , FanDuelPosition               VARCHAR(255)
    , DraftKingsPosition            VARCHAR(255)
    , YahooPosition                 VARCHAR(255)
    , MondogoalPosition             VARCHAR(255)
    , InjuryStatus                  VARCHAR(255)
    , InjuryBodyPart                VARCHAR(255)
    , InjuryNotes                   VARCHAR(255)
    , InjuryStartDate               TIMESTAMP
    , GlobalTeamId                  INT
    , GameId                        INT
    , OpponentId                    INT
    , Opponent                      VARCHAR(255)
    , Day                           TIMESTAMP
    , DateTime                      TIMESTAMP
    , HomeOrAway                    VARCHAR(255)
    , IsGameOver                    BOOLEAN
    , GlobalGameId                  INT
    , GlobalOpponentId              INT
    , Updated                       TIMESTAMP
    , UpdatedUtc                    TIMESTAMP
    , Games                         INT
    , FantasyPoints                 FLOAT
    , FantasyPointsFanDuel          VARCHAR(255)
    , FantasyPointsDraftKings       FLOAT
    , FantasyPointsYahoo            VARCHAR(255)
    , FantasyPointsMondogoal        FLOAT
    , Minutes                       FLOAT
    , Goals                         FLOAT
    , Assists                       FLOAT
    , Shots                         FLOAT
    , ShotsOnGoal                   FLOAT
    , YellowCards                   FLOAT
    , RedCards                      FLOAT
    , YellowRedCards                FLOAT
    , Crosses                       FLOAT
    , TacklesWon                    FLOAT
    , Interceptions                 FLOAT
    , OwnGoals                      FLOAT
    , Fouls                         FLOAT
    , Fouled                        FLOAT
    , Offsides                      FLOAT
    , Passes                        FLOAT
    , PassesCompleted               FLOAT
    , LastManTackle                 FLOAT
    , CornersWon                    FLOAT
    , BlockedShots                  FLOAT
    , Touches                       FLOAT
    , DefenderCleanSheets           FLOAT
    , GoalkeeperSaves               FLOAT
    , GoalkeeperGoalsAgainst        FLOAT
    , GoalkeeperSingleGoalAgainst   FLOAT
    , GoalkeeperCleanSheets         FLOAT
    , GoalkeeperWins                FLOAT
    , PenaltyKickGoals              FLOAT
    , PenaltyKickMisses             FLOAT
    , PenaltyKickSaves              FLOAT
    , PenaltiesWon                  FLOAT
    , PenaltiesConceded             FLOAT
    , Score                         FLOAT
    , OpponentScore                 FLOAT
    , Tackles                       FLOAT
);
""")

# %%
## Fetch and save in database game schedules for the 2025 spanish season
df = get_soccer_data('scores','SchedulesBasic','ESP','2025')
df = prepare_df(df,'Group','Group_num')
df_to_posgres (user, host, password, database, df, 'schedule','staging')
# Out:
# https://api.sportsdata.io/v4/soccer/scores/json/SchedulesBasic/ESP/2025
# Status Code: 200
# ✅ Saved: SchedulesBasic_ESP_2025.json and SchedulesBasic_ESP_2025.csv

# %%
## Get gameid for all games in season 
pgcursor.execute('SELECT DISTINCT gameid from staging.schedule')
gameid_2025_esp = pgcursor.fetchall()
gameid_2025_esp = [str(x[0]) for x in gameid_2025_esp] # Cast gameid to string

# %%
schema = 'staging'  
gameid_errors = []  # list to record gameid with errors 
records = len(gameid_2025_esp) # total of records 
for i in gameid_2025_esp[0:]: # for all gamesid (all games from season 2025)
    try:
        df = get_soccer_data('Stats','BoxScoreFinal','ESP',i) #Fetch data from gameid
        Game_df = prepare_df(pd.json_normalize(df['Game'][0]), 'Group','Group_num') # save game data to Dataframe
        AwayTeamCoach_df = prepare_df(pd.json_normalize(df['AwayTeamCoach'])) 
        HomeTeamCoach_df = prepare_df(pd.json_normalize(df['HomeTeamCoach'])) 
        MainReferee_df = prepare_df(pd.json_normalize(df['MainReferee'])) 
        AssistantReferee1_df = prepare_df(pd.json_normalize(df['AssistantReferee1'])) 
        AssistantReferee2_df = prepare_df(pd.json_normalize(df['AssistantReferee2'])) 
        FourthReferee_df = prepare_df(pd.json_normalize(df['FourthReferee'])) 
        VideoAssistantReferee_df = prepare_df(pd.json_normalize(df['VideoAssistantReferee'])) 
        Lineups_df = prepare_df(pd.json_normalize(df['Lineups'][0])) 
        Goals_df = pd.json_normalize(df['Goals'][0]) 
        Bookings_df = pd.json_normalize(df['Bookings'][0]) 
        TeamGames_df = prepare_df(pd.json_normalize(df['TeamGames'][0]))
        PlayerGames_df = prepare_df(pd.json_normalize(df['PlayerGames'][0]))
        Game_df.loc[0, 'awayteamcoachid'] = AwayTeamCoach_df['coachid'][0] # Add to Game_df relationships for coachs and referees
        Game_df.loc[0, 'hometeamcoachid'] = HomeTeamCoach_df['coachid'][0]
        Game_df.loc[0, 'mainreferee'] = MainReferee_df['refereeid'][0]
        Game_df.loc[0, 'assistantreferee1'] = AssistantReferee1_df['refereeid'][0]
        Game_df.loc[0, 'assistantreferee2'] = AssistantReferee2_df['refereeid'][0]
        Game_df.loc[0, 'fourthreferee'] = FourthReferee_df['refereeid'][0]
        Game_df.loc[0, 'videoassistantreferee'] = VideoAssistantReferee_df['refereeid'][0]
        df_to_posgres(user, host, password, database, AwayTeamCoach_df,'coaches',schema) # Save in database
        df_to_posgres(user, host, password, database, HomeTeamCoach_df,'coaches',schema)
        df_to_posgres(user, host, password, database, MainReferee_df,'referees',schema)
        df_to_posgres(user, host, password, database, AssistantReferee1_df,'referees',schema)
        df_to_posgres(user, host, password, database, AssistantReferee2_df,'referees',schema)
        df_to_posgres(user, host, password, database, FourthReferee_df,'referees',schema)
        df_to_posgres(user, host, password, database, VideoAssistantReferee_df,'referees',schema)
        df_to_posgres(user, host, password, database, Lineups_df,'lineups',schema)
        if len(Goals_df.columns) > 0: # Check if the game had goals
            Goals_df = prepare_df(Goals_df)
            df_to_posgres(user, host, password, database, Goals_df,'goals',schema)
        if len(Bookings_df.columns) > 0: # Check if the game had bookings
            Bookings_df = prepare_df(Bookings_df)
            df_to_posgres(user, host, password, database, Bookings_df,'bookings',schema)
        df_to_posgres(user, host, password, database, TeamGames_df,'teamgames',schema)
        df_to_posgres(user, host, password, database, PlayerGames_df,'playerteams',schema)
        df_to_posgres(user, host, password, database, Game_df,'games',schema)
        print(f'{gameid_2025_esp.index(i)+1}/{records} processed') # print general progress
    except Exception as e:
        print(f"An error occurred: {e}, when saving record {i}") # print error
        gameid_errors.append(i) # record gameid with error
        log_exception(e) # save error to file
        print(f'{gameid_2025_esp.index(i)+1}/{records} processed') # print general progress
# Out:
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79260
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79260.json and BoxScoreFinal_ESP_79260.csv
# 1/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79433
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79433.json and BoxScoreFinal_ESP_79433.csv
# 2/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79431
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79431.json and BoxScoreFinal_ESP_79431.csv
# 3/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79326
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79326.json and BoxScoreFinal_ESP_79326.csv
# 4/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79258
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79258.json and BoxScoreFinal_ESP_79258.csv
# 5/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79467
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79467.json and BoxScoreFinal_ESP_79467.csv
# 6/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79329
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79329.json and BoxScoreFinal_ESP_79329.csv
# 7/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79148
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79148.json and BoxScoreFinal_ESP_79148.csv
# 8/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79374
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79374.json and BoxScoreFinal_ESP_79374.csv
# 9/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79234
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79234.json and BoxScoreFinal_ESP_79234.csv
# 10/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79334
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79334.json and BoxScoreFinal_ESP_79334.csv
# 11/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79231
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79231.json and BoxScoreFinal_ESP_79231.csv
# 12/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79270
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79270.json and BoxScoreFinal_ESP_79270.csv
# 13/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79184
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79184.json and BoxScoreFinal_ESP_79184.csv
# 14/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79199
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79199.json and BoxScoreFinal_ESP_79199.csv
# 15/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79386
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79386.json and BoxScoreFinal_ESP_79386.csv
# 16/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79437
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79437.json and BoxScoreFinal_ESP_79437.csv
# 17/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79459
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79459.json and BoxScoreFinal_ESP_79459.csv
# 18/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79385
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79385.json and BoxScoreFinal_ESP_79385.csv
# 19/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79274
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79274.json and BoxScoreFinal_ESP_79274.csv
# 20/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79378
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79378.json and BoxScoreFinal_ESP_79378.csv
# 21/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79354
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79354.json and BoxScoreFinal_ESP_79354.csv
# 22/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79195
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79195.json and BoxScoreFinal_ESP_79195.csv
# 23/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79368
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79368.json and BoxScoreFinal_ESP_79368.csv
# 24/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79497
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79497.json and BoxScoreFinal_ESP_79497.csv
# 25/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79125
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79125.json and BoxScoreFinal_ESP_79125.csv
# 26/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79392
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79392.json and BoxScoreFinal_ESP_79392.csv
# 27/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79457
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79457.json and BoxScoreFinal_ESP_79457.csv
# 28/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79484
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79484.json and BoxScoreFinal_ESP_79484.csv
# 29/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79482
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79482.json and BoxScoreFinal_ESP_79482.csv
# 30/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79218
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79218.json and BoxScoreFinal_ESP_79218.csv
# 31/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79429
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79429.json and BoxScoreFinal_ESP_79429.csv
# 32/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79446
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79446.json and BoxScoreFinal_ESP_79446.csv
# 33/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79327
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79327.json and BoxScoreFinal_ESP_79327.csv
# 34/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79421
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79421.json and BoxScoreFinal_ESP_79421.csv
# 35/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79298
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79298.json and BoxScoreFinal_ESP_79298.csv
# 36/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79472
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79472.json and BoxScoreFinal_ESP_79472.csv
# 37/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79296
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79296.json and BoxScoreFinal_ESP_79296.csv
# 38/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79268
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79268.json and BoxScoreFinal_ESP_79268.csv
# 39/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79225
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79225.json and BoxScoreFinal_ESP_79225.csv
# 40/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79447
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79447.json and BoxScoreFinal_ESP_79447.csv
# 41/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79273
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79273.json and BoxScoreFinal_ESP_79273.csv
# 42/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79134
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79134.json and BoxScoreFinal_ESP_79134.csv
# 43/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79319
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79319.json and BoxScoreFinal_ESP_79319.csv
# 44/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79253
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79253.json and BoxScoreFinal_ESP_79253.csv
# 45/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79173
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79173.json and BoxScoreFinal_ESP_79173.csv
# 46/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79409
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79409.json and BoxScoreFinal_ESP_79409.csv
# 47/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79171
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79171.json and BoxScoreFinal_ESP_79171.csv
# 48/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79402
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79402.json and BoxScoreFinal_ESP_79402.csv
# 49/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79157
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79157.json and BoxScoreFinal_ESP_79157.csv
# 50/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79227
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79227.json and BoxScoreFinal_ESP_79227.csv
# 51/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79276
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79276.json and BoxScoreFinal_ESP_79276.csv
# 52/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79301
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79301.json and BoxScoreFinal_ESP_79301.csv
# 53/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79435
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79435.json and BoxScoreFinal_ESP_79435.csv
# 54/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79499
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79499.json and BoxScoreFinal_ESP_79499.csv
# 55/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79343
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79343.json and BoxScoreFinal_ESP_79343.csv
# 56/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79126
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79126.json and BoxScoreFinal_ESP_79126.csv
# 57/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79223
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79223.json and BoxScoreFinal_ESP_79223.csv
# 58/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79216
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79216.json and BoxScoreFinal_ESP_79216.csv
# 59/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79357
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79357.json and BoxScoreFinal_ESP_79357.csv
# 60/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79492
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79492.json and BoxScoreFinal_ESP_79492.csv
# 61/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79238
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79238.json and BoxScoreFinal_ESP_79238.csv
# 62/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79313
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79313.json and BoxScoreFinal_ESP_79313.csv
# 63/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79344
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79344.json and BoxScoreFinal_ESP_79344.csv
# 64/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79228
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79228.json and BoxScoreFinal_ESP_79228.csv
# 65/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79478
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79478.json and BoxScoreFinal_ESP_79478.csv
# 66/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79483
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79483.json and BoxScoreFinal_ESP_79483.csv
# 67/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79434
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79434.json and BoxScoreFinal_ESP_79434.csv
# 68/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79183
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79183.json and BoxScoreFinal_ESP_79183.csv
# 69/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79347
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79347.json and BoxScoreFinal_ESP_79347.csv
# 70/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79469
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79469.json and BoxScoreFinal_ESP_79469.csv
# 71/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79416
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79416.json and BoxScoreFinal_ESP_79416.csv
# 72/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79341
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79341.json and BoxScoreFinal_ESP_79341.csv
# 73/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79153
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79153.json and BoxScoreFinal_ESP_79153.csv
# 74/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79331
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79331.json and BoxScoreFinal_ESP_79331.csv
# 75/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79256
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79256.json and BoxScoreFinal_ESP_79256.csv
# 76/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79414
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79414.json and BoxScoreFinal_ESP_79414.csv
# 77/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79128
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79128.json and BoxScoreFinal_ESP_79128.csv
# 78/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79293
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79293.json and BoxScoreFinal_ESP_79293.csv
# 79/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79286
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79286.json and BoxScoreFinal_ESP_79286.csv
# 80/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79122
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79122.json and BoxScoreFinal_ESP_79122.csv
# 81/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79393
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79393.json and BoxScoreFinal_ESP_79393.csv
# 82/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79311
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79311.json and BoxScoreFinal_ESP_79311.csv
# 83/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79291
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79291.json and BoxScoreFinal_ESP_79291.csv
# 84/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79373
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79373.json and BoxScoreFinal_ESP_79373.csv
# 85/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79312
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79312.json and BoxScoreFinal_ESP_79312.csv
# 86/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79305
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79305.json and BoxScoreFinal_ESP_79305.csv
# 87/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79130
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79130.json and BoxScoreFinal_ESP_79130.csv
# 88/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79353
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79353.json and BoxScoreFinal_ESP_79353.csv
# 89/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79352
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79352.json and BoxScoreFinal_ESP_79352.csv
# 90/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79403
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79403.json and BoxScoreFinal_ESP_79403.csv
# 91/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79322
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79322.json and BoxScoreFinal_ESP_79322.csv
# 92/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79438
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79438.json and BoxScoreFinal_ESP_79438.csv
# 93/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79178
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79178.json and BoxScoreFinal_ESP_79178.csv
# 94/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79201
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79201.json and BoxScoreFinal_ESP_79201.csv
# 95/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79325
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79325.json and BoxScoreFinal_ESP_79325.csv
# 96/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79318
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79318.json and BoxScoreFinal_ESP_79318.csv
# 97/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79123
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79123.json and BoxScoreFinal_ESP_79123.csv
# 98/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79346
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79346.json and BoxScoreFinal_ESP_79346.csv
# 99/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79282
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79282.json and BoxScoreFinal_ESP_79282.csv
# 100/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79242
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79242.json and BoxScoreFinal_ESP_79242.csv
# 101/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79203
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79203.json and BoxScoreFinal_ESP_79203.csv
# 102/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79490
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79490.json and BoxScoreFinal_ESP_79490.csv
# 103/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79249
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79249.json and BoxScoreFinal_ESP_79249.csv
# 104/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79330
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79330.json and BoxScoreFinal_ESP_79330.csv
# 105/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79271
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79271.json and BoxScoreFinal_ESP_79271.csv
# 106/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79241
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79241.json and BoxScoreFinal_ESP_79241.csv
# 107/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79323
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79323.json and BoxScoreFinal_ESP_79323.csv
# 108/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79288
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79288.json and BoxScoreFinal_ESP_79288.csv
# 109/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79300
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79300.json and BoxScoreFinal_ESP_79300.csv
# 110/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79160
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79160.json and BoxScoreFinal_ESP_79160.csv
# 111/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79306
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79306.json and BoxScoreFinal_ESP_79306.csv
# 112/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79170
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79170.json and BoxScoreFinal_ESP_79170.csv
# 113/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79477
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79477.json and BoxScoreFinal_ESP_79477.csv
# 114/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79279
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79279.json and BoxScoreFinal_ESP_79279.csv
# 115/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79355
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79355.json and BoxScoreFinal_ESP_79355.csv
# 116/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79367
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79367.json and BoxScoreFinal_ESP_79367.csv
# 117/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79456
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79456.json and BoxScoreFinal_ESP_79456.csv
# 118/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79451
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79451.json and BoxScoreFinal_ESP_79451.csv
# 119/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79333
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79333.json and BoxScoreFinal_ESP_79333.csv
# 120/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79285
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79285.json and BoxScoreFinal_ESP_79285.csv
# 121/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79485
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79485.json and BoxScoreFinal_ESP_79485.csv
# 122/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79287
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79287.json and BoxScoreFinal_ESP_79287.csv
# 123/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79243
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79243.json and BoxScoreFinal_ESP_79243.csv
# 124/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79269
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79269.json and BoxScoreFinal_ESP_79269.csv
# 125/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79255
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79255.json and BoxScoreFinal_ESP_79255.csv
# 126/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79177
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79177.json and BoxScoreFinal_ESP_79177.csv
# 127/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79443
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79443.json and BoxScoreFinal_ESP_79443.csv
# 128/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79350
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79350.json and BoxScoreFinal_ESP_79350.csv
# 129/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79181
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79181.json and BoxScoreFinal_ESP_79181.csv
# 130/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79470
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79470.json and BoxScoreFinal_ESP_79470.csv
# 131/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79233
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79233.json and BoxScoreFinal_ESP_79233.csv
# 132/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79254
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79254.json and BoxScoreFinal_ESP_79254.csv
# 133/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79210
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79210.json and BoxScoreFinal_ESP_79210.csv
# 134/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79280
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79280.json and BoxScoreFinal_ESP_79280.csv
# 135/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79474
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79474.json and BoxScoreFinal_ESP_79474.csv
# 136/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79290
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79290.json and BoxScoreFinal_ESP_79290.csv
# 137/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79479
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79479.json and BoxScoreFinal_ESP_79479.csv
# 138/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79141
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79141.json and BoxScoreFinal_ESP_79141.csv
# 139/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79244
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79244.json and BoxScoreFinal_ESP_79244.csv
# 140/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79161
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79161.json and BoxScoreFinal_ESP_79161.csv
# 141/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79369
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79369.json and BoxScoreFinal_ESP_79369.csv
# 142/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79337
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79337.json and BoxScoreFinal_ESP_79337.csv
# 143/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79398
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79398.json and BoxScoreFinal_ESP_79398.csv
# 144/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79198
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79198.json and BoxScoreFinal_ESP_79198.csv
# 145/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79240
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79240.json and BoxScoreFinal_ESP_79240.csv
# 146/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79450
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79450.json and BoxScoreFinal_ESP_79450.csv
# 147/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79137
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79137.json and BoxScoreFinal_ESP_79137.csv
# 148/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79382
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79382.json and BoxScoreFinal_ESP_79382.csv
# 149/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79292
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79292.json and BoxScoreFinal_ESP_79292.csv
# 150/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79452
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79452.json and BoxScoreFinal_ESP_79452.csv
# 151/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79156
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79156.json and BoxScoreFinal_ESP_79156.csv
# 152/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79307
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79307.json and BoxScoreFinal_ESP_79307.csv
# 153/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79362
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79362.json and BoxScoreFinal_ESP_79362.csv
# 154/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79193
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79193.json and BoxScoreFinal_ESP_79193.csv
# 155/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79420
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79420.json and BoxScoreFinal_ESP_79420.csv
# 156/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79395
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79395.json and BoxScoreFinal_ESP_79395.csv
# 157/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79498
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79498.json and BoxScoreFinal_ESP_79498.csv
# 158/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79264
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79264.json and BoxScoreFinal_ESP_79264.csv
# 159/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79284
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79284.json and BoxScoreFinal_ESP_79284.csv
# 160/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79480
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79480.json and BoxScoreFinal_ESP_79480.csv
# 161/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79442
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79442.json and BoxScoreFinal_ESP_79442.csv
# 162/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79427
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79427.json and BoxScoreFinal_ESP_79427.csv
# 163/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79174
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79174.json and BoxScoreFinal_ESP_79174.csv
# 164/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79149
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79149.json and BoxScoreFinal_ESP_79149.csv
# 165/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79418
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79418.json and BoxScoreFinal_ESP_79418.csv
# 166/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79349
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79349.json and BoxScoreFinal_ESP_79349.csv
# 167/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79411
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79411.json and BoxScoreFinal_ESP_79411.csv
# 168/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79224
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79224.json and BoxScoreFinal_ESP_79224.csv
# 169/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79310
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79310.json and BoxScoreFinal_ESP_79310.csv
# 170/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79302
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79302.json and BoxScoreFinal_ESP_79302.csv
# 171/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79144
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79144.json and BoxScoreFinal_ESP_79144.csv
# 172/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79419
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79419.json and BoxScoreFinal_ESP_79419.csv
# 173/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79345
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79345.json and BoxScoreFinal_ESP_79345.csv
# 174/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79265
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79265.json and BoxScoreFinal_ESP_79265.csv
# 175/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79145
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79145.json and BoxScoreFinal_ESP_79145.csv
# 176/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79295
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79295.json and BoxScoreFinal_ESP_79295.csv
# 177/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79208
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79208.json and BoxScoreFinal_ESP_79208.csv
# 178/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79237
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79237.json and BoxScoreFinal_ESP_79237.csv
# 179/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79250
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79250.json and BoxScoreFinal_ESP_79250.csv
# 180/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79460
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79460.json and BoxScoreFinal_ESP_79460.csv
# 181/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79410
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79410.json and BoxScoreFinal_ESP_79410.csv
# 182/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79448
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79448.json and BoxScoreFinal_ESP_79448.csv
# 183/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79328
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79328.json and BoxScoreFinal_ESP_79328.csv
# 184/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79314
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79314.json and BoxScoreFinal_ESP_79314.csv
# 185/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79404
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79404.json and BoxScoreFinal_ESP_79404.csv
# 186/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79262
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79262.json and BoxScoreFinal_ESP_79262.csv
# 187/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79232
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79232.json and BoxScoreFinal_ESP_79232.csv
# 188/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79465
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79465.json and BoxScoreFinal_ESP_79465.csv
# 189/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79388
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79388.json and BoxScoreFinal_ESP_79388.csv
# 190/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79289
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79289.json and BoxScoreFinal_ESP_79289.csv
# 191/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79324
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79324.json and BoxScoreFinal_ESP_79324.csv
# 192/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79180
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79180.json and BoxScoreFinal_ESP_79180.csv
# 193/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79397
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79397.json and BoxScoreFinal_ESP_79397.csv
# 194/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79229
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79229.json and BoxScoreFinal_ESP_79229.csv
# 195/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79356
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79356.json and BoxScoreFinal_ESP_79356.csv
# 196/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79364
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79364.json and BoxScoreFinal_ESP_79364.csv
# 197/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79308
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79308.json and BoxScoreFinal_ESP_79308.csv
# 198/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79360
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79360.json and BoxScoreFinal_ESP_79360.csv
# 199/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79143
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79143.json and BoxScoreFinal_ESP_79143.csv
# 200/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79487
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79487.json and BoxScoreFinal_ESP_79487.csv
# 201/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79496
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79496.json and BoxScoreFinal_ESP_79496.csv
# 202/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79215
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79215.json and BoxScoreFinal_ESP_79215.csv
# 203/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79272
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79272.json and BoxScoreFinal_ESP_79272.csv
# 204/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79335
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79335.json and BoxScoreFinal_ESP_79335.csv
# 205/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79464
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79464.json and BoxScoreFinal_ESP_79464.csv
# 206/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79175
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79175.json and BoxScoreFinal_ESP_79175.csv
# 207/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79309
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79309.json and BoxScoreFinal_ESP_79309.csv
# 208/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79277
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79277.json and BoxScoreFinal_ESP_79277.csv
# 209/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79226
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79226.json and BoxScoreFinal_ESP_79226.csv
# 210/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79317
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79317.json and BoxScoreFinal_ESP_79317.csv
# 211/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79220
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79220.json and BoxScoreFinal_ESP_79220.csv
# 212/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79158
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79158.json and BoxScoreFinal_ESP_79158.csv
# 213/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79340
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79340.json and BoxScoreFinal_ESP_79340.csv
# 214/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79164
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79164.json and BoxScoreFinal_ESP_79164.csv
# 215/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79162
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79162.json and BoxScoreFinal_ESP_79162.csv
# 216/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79167
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79167.json and BoxScoreFinal_ESP_79167.csv
# 217/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79489
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79489.json and BoxScoreFinal_ESP_79489.csv
# 218/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79415
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79415.json and BoxScoreFinal_ESP_79415.csv
# 219/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79133
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79133.json and BoxScoreFinal_ESP_79133.csv
# 220/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79127
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79127.json and BoxScoreFinal_ESP_79127.csv
# 221/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79299
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79299.json and BoxScoreFinal_ESP_79299.csv
# 222/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79261
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79261.json and BoxScoreFinal_ESP_79261.csv
# 223/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79205
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79205.json and BoxScoreFinal_ESP_79205.csv
# 224/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79458
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79458.json and BoxScoreFinal_ESP_79458.csv
# 225/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79432
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79432.json and BoxScoreFinal_ESP_79432.csv
# 226/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79380
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79380.json and BoxScoreFinal_ESP_79380.csv
# 227/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79371
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79371.json and BoxScoreFinal_ESP_79371.csv
# 228/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79248
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79248.json and BoxScoreFinal_ESP_79248.csv
# 229/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79129
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79129.json and BoxScoreFinal_ESP_79129.csv
# 230/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79462
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79462.json and BoxScoreFinal_ESP_79462.csv
# 231/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79391
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79391.json and BoxScoreFinal_ESP_79391.csv
# 232/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79236
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79236.json and BoxScoreFinal_ESP_79236.csv
# 233/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79188
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79188.json and BoxScoreFinal_ESP_79188.csv
# 234/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79439
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79439.json and BoxScoreFinal_ESP_79439.csv
# 235/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79445
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79445.json and BoxScoreFinal_ESP_79445.csv
# 236/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79202
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79202.json and BoxScoreFinal_ESP_79202.csv
# 237/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79440
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79440.json and BoxScoreFinal_ESP_79440.csv
# 238/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79366
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79366.json and BoxScoreFinal_ESP_79366.csv
# 239/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79146
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79146.json and BoxScoreFinal_ESP_79146.csv
# 240/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79196
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79196.json and BoxScoreFinal_ESP_79196.csv
# 241/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79358
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79358.json and BoxScoreFinal_ESP_79358.csv
# 242/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79230
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79230.json and BoxScoreFinal_ESP_79230.csv
# 243/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79140
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79140.json and BoxScoreFinal_ESP_79140.csv
# 244/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79370
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79370.json and BoxScoreFinal_ESP_79370.csv
# 245/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79342
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79342.json and BoxScoreFinal_ESP_79342.csv
# 246/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79211
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79211.json and BoxScoreFinal_ESP_79211.csv
# 247/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79413
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79413.json and BoxScoreFinal_ESP_79413.csv
# 248/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79473
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79473.json and BoxScoreFinal_ESP_79473.csv
# 249/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79461
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79461.json and BoxScoreFinal_ESP_79461.csv
# 250/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79381
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79381.json and BoxScoreFinal_ESP_79381.csv
# 251/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79207
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79207.json and BoxScoreFinal_ESP_79207.csv
# 252/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79189
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79189.json and BoxScoreFinal_ESP_79189.csv
# 253/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79471
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79471.json and BoxScoreFinal_ESP_79471.csv
# 254/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79486
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79486.json and BoxScoreFinal_ESP_79486.csv
# 255/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79182
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79182.json and BoxScoreFinal_ESP_79182.csv
# 256/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79315
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79315.json and BoxScoreFinal_ESP_79315.csv
# 257/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79142
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79142.json and BoxScoreFinal_ESP_79142.csv
# 258/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79138
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79138.json and BoxScoreFinal_ESP_79138.csv
# 259/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79441
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79441.json and BoxScoreFinal_ESP_79441.csv
# 260/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79401
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79401.json and BoxScoreFinal_ESP_79401.csv
# 261/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79266
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79266.json and BoxScoreFinal_ESP_79266.csv
# 262/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79408
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79408.json and BoxScoreFinal_ESP_79408.csv
# 263/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79400
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79400.json and BoxScoreFinal_ESP_79400.csv
# 264/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79197
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79197.json and BoxScoreFinal_ESP_79197.csv
# 265/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79121
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79121.json and BoxScoreFinal_ESP_79121.csv
# 266/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79455
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79455.json and BoxScoreFinal_ESP_79455.csv
# 267/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79247
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79247.json and BoxScoreFinal_ESP_79247.csv
# 268/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79176
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79176.json and BoxScoreFinal_ESP_79176.csv
# 269/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79348
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79348.json and BoxScoreFinal_ESP_79348.csv
# 270/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79147
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79147.json and BoxScoreFinal_ESP_79147.csv
# 271/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79159
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79159.json and BoxScoreFinal_ESP_79159.csv
# 272/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79283
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79283.json and BoxScoreFinal_ESP_79283.csv
# 273/380 processed
# ...
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79476.json and BoxScoreFinal_ESP_79476.csv
# 290/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79453
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79453.json and BoxScoreFinal_ESP_79453.csv
# 291/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79278
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79278.json and BoxScoreFinal_ESP_79278.csv
# 292/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79191
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79191.json and BoxScoreFinal_ESP_79191.csv
# 293/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79359
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79359.json and BoxScoreFinal_ESP_79359.csv
# 294/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79275
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79275.json and BoxScoreFinal_ESP_79275.csv
# 295/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79259
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79259.json and BoxScoreFinal_ESP_79259.csv
# 296/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79154
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79154.json and BoxScoreFinal_ESP_79154.csv
# 297/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79425
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79425.json and BoxScoreFinal_ESP_79425.csv
# 298/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79338
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79338.json and BoxScoreFinal_ESP_79338.csv
# 299/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79151
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79151.json and BoxScoreFinal_ESP_79151.csv
# 300/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79267
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79267.json and BoxScoreFinal_ESP_79267.csv
# 301/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79219
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79219.json and BoxScoreFinal_ESP_79219.csv
# 302/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79336
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79336.json and BoxScoreFinal_ESP_79336.csv
# 303/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79428
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79428.json and BoxScoreFinal_ESP_79428.csv
# 304/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79135
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79135.json and BoxScoreFinal_ESP_79135.csv
# 305/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79221
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79221.json and BoxScoreFinal_ESP_79221.csv
# 306/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79136
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79136.json and BoxScoreFinal_ESP_79136.csv
# 307/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79339
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79339.json and BoxScoreFinal_ESP_79339.csv
# 308/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79179
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79179.json and BoxScoreFinal_ESP_79179.csv
# 309/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79436
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79436.json and BoxScoreFinal_ESP_79436.csv
# 310/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79186
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79186.json and BoxScoreFinal_ESP_79186.csv
# 311/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79120
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79120.json and BoxScoreFinal_ESP_79120.csv
# 312/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79422
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79422.json and BoxScoreFinal_ESP_79422.csv
# 313/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79379
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79379.json and BoxScoreFinal_ESP_79379.csv
# 314/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79426
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79426.json and BoxScoreFinal_ESP_79426.csv
# 315/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79187
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79187.json and BoxScoreFinal_ESP_79187.csv
# 316/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79423
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79423.json and BoxScoreFinal_ESP_79423.csv
# 317/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79304
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79304.json and BoxScoreFinal_ESP_79304.csv
# 318/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79222
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79222.json and BoxScoreFinal_ESP_79222.csv
# 319/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79412
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79412.json and BoxScoreFinal_ESP_79412.csv
# 320/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79365
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79365.json and BoxScoreFinal_ESP_79365.csv
# 321/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79316
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79316.json and BoxScoreFinal_ESP_79316.csv
# 322/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79155
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79155.json and BoxScoreFinal_ESP_79155.csv
# 323/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79257
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79257.json and BoxScoreFinal_ESP_79257.csv
# 324/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79251
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79251.json and BoxScoreFinal_ESP_79251.csv
# 325/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79417
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79417.json and BoxScoreFinal_ESP_79417.csv
# 326/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79463
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79463.json and BoxScoreFinal_ESP_79463.csv
# 327/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79332
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79332.json and BoxScoreFinal_ESP_79332.csv
# 328/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79204
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79204.json and BoxScoreFinal_ESP_79204.csv
# 329/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79390
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79390.json and BoxScoreFinal_ESP_79390.csv
# 330/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79389
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79389.json and BoxScoreFinal_ESP_79389.csv
# 331/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79297
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79297.json and BoxScoreFinal_ESP_79297.csv
# 332/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79132
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79132.json and BoxScoreFinal_ESP_79132.csv
# 333/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79139
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79139.json and BoxScoreFinal_ESP_79139.csv
# 334/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79491
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79491.json and BoxScoreFinal_ESP_79491.csv
# 335/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79407
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79407.json and BoxScoreFinal_ESP_79407.csv
# 336/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79185
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79185.json and BoxScoreFinal_ESP_79185.csv
# 337/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79124
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79124.json and BoxScoreFinal_ESP_79124.csv
# 338/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79449
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79449.json and BoxScoreFinal_ESP_79449.csv
# 339/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79263
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79263.json and BoxScoreFinal_ESP_79263.csv
# 340/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79252
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79252.json and BoxScoreFinal_ESP_79252.csv
# 341/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79321
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79321.json and BoxScoreFinal_ESP_79321.csv
# 342/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79206
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79206.json and BoxScoreFinal_ESP_79206.csv
# 343/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79294
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79294.json and BoxScoreFinal_ESP_79294.csv
# 344/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79405
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79405.json and BoxScoreFinal_ESP_79405.csv
# 345/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79168
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79168.json and BoxScoreFinal_ESP_79168.csv
# 346/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79430
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79430.json and BoxScoreFinal_ESP_79430.csv
# 347/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79495
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79495.json and BoxScoreFinal_ESP_79495.csv
# 348/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79406
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79406.json and BoxScoreFinal_ESP_79406.csv
# 349/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79150
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79150.json and BoxScoreFinal_ESP_79150.csv
# 350/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79454
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79454.json and BoxScoreFinal_ESP_79454.csv
# 351/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79399
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79399.json and BoxScoreFinal_ESP_79399.csv
# 352/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79383
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79383.json and BoxScoreFinal_ESP_79383.csv
# 353/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79246
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79246.json and BoxScoreFinal_ESP_79246.csv
# 354/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79131
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79131.json and BoxScoreFinal_ESP_79131.csv
# 355/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79192
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79192.json and BoxScoreFinal_ESP_79192.csv
# 356/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79493
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79493.json and BoxScoreFinal_ESP_79493.csv
# 357/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79239
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79239.json and BoxScoreFinal_ESP_79239.csv
# 358/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79377
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79377.json and BoxScoreFinal_ESP_79377.csv
# 359/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79363
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79363.json and BoxScoreFinal_ESP_79363.csv
# 360/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79424
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79424.json and BoxScoreFinal_ESP_79424.csv
# 361/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79384
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79384.json and BoxScoreFinal_ESP_79384.csv
# 362/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79245
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79245.json and BoxScoreFinal_ESP_79245.csv
# 363/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79166
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79166.json and BoxScoreFinal_ESP_79166.csv
# 364/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79494
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79494.json and BoxScoreFinal_ESP_79494.csv
# 365/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79387
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79387.json and BoxScoreFinal_ESP_79387.csv
# 366/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79152
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79152.json and BoxScoreFinal_ESP_79152.csv
# 367/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79375
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79375.json and BoxScoreFinal_ESP_79375.csv
# 368/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79394
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79394.json and BoxScoreFinal_ESP_79394.csv
# 369/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79488
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79488.json and BoxScoreFinal_ESP_79488.csv
# 370/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79235
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79235.json and BoxScoreFinal_ESP_79235.csv
# 371/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79475
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79475.json and BoxScoreFinal_ESP_79475.csv
# 372/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79163
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79163.json and BoxScoreFinal_ESP_79163.csv
# 373/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79444
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79444.json and BoxScoreFinal_ESP_79444.csv
# 374/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79351
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79351.json and BoxScoreFinal_ESP_79351.csv
# 375/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79213
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79213.json and BoxScoreFinal_ESP_79213.csv
# 376/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79209
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79209.json and BoxScoreFinal_ESP_79209.csv
# 377/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79172
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79172.json and BoxScoreFinal_ESP_79172.csv
# 378/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79468
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79468.json and BoxScoreFinal_ESP_79468.csv
# 379/380 processed
# https://api.sportsdata.io/v4/soccer/Stats/json/BoxScoreFinal/ESP/79217
# Status Code: 200
# ✅ Saved: BoxScoreFinal_ESP_79217.json and BoxScoreFinal_ESP_79217.csv
# 380/380 processed

# %%
print(gameid_errors) # check if errors occurred
# Out:
# []
